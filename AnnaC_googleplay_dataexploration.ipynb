# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
googleplaydata = pd.read_csv('/Users/annachesson/desktop/cognitivesystems/googleplaystoreapps/googleplaystore2.csv', sep=';', encoding="ISO-8859-1")

# %%
#this is a pandas datafrmae
googleplaydata
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite â FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
category = googleplaydata['Category']

# %%
category.describe()
# Out:
# count      10841
# unique        34
# top       FAMILY
# freq        1972
# Name: Category, dtype: object

# %%
sns.countplot(category, orient = 'h', palette = 'Spectral').set_title("Number of Apps by Category")
# Out:
# Text(0.5, 1.0, 'Number of Apps by Category')

# %%
Type = googleplaydata['Type']

# %%
sns.countplot(Type, orient = 'h', palette = 'Spectral').set_title("Type- Free or Paid")
# Out:
# Text(0.5, 1.0, 'Type- Free or Paid')

# %%
Type.describe()
# Out:
# count     10840
# unique        3
# top        Free
# freq      10039
# Name: Type, dtype: object

# %%
Content = googleplaydata['Content Rating']

# %%
sns.countplot(Content, orient = 'h', palette = 'Spectral').set_title("Content Rating")
# Out:
# Text(0.5, 1.0, 'Content Rating')

# %%
Content.describe()
# Out:
# count        10840
# unique           6
# top       Everyone
# freq          8714
# Name: Content Rating, dtype: object

# %%
googleplaydata.describe()

# %%
Installs = googleplaydata['Installs']

# %%
sns.countplot(Installs, orient = 'h', palette = 'Spectral').set_title("Installs")
# Out:
# Text(0.5, 1.0, 'Installs')

# %%
reviews = googleplaydata['Reviews']
reviews.describe()
# Out:
# count    1.084000e+04
# mean     4.441529e+05
# std      2.927761e+06
# min      0.000000e+00
# 25%      3.800000e+01
# 50%      2.094000e+03
# 75%      5.477550e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
sns.barplot(reviews, palette="Spectral").set_title("Reviews")
# Out:
# Text(0.5, 1.0, 'Reviews')

# %%
Size = googleplaydata['Size']

# %%
sns.barplot(rating, palette="Spectral").set_title("Rating")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-c5c92fb016a7> in <module>()
# ----> 1 sns.barplot(rating, palette="Spectral").set_title("Rating")
#
# ~/anaconda3/lib/python3.5/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~/anaconda3/lib/python3.5/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
googleplaydata.dtypes
# Out:
# App                object
# Category           object
# Rating             object
# Reviews           float64
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#detects missing values
googleplaydata.isna().sum()

# %%
#look at Size since it's a factor"
googleplaydata['Size'].value_counts()

# %%
sns.countplot(googleplaydata['Size'], palette = 'Spectral').set_title("Size of Apps")
#plt.ylim(0,400)

# %%
googleplaydata['Category'].value_counts()

# %%
#drop the first column which contaings strings of the names of the apps, returns a series
cluster_googleplaydata = googleplaydata.drop(['Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type','Content Rating'], axis=1)

# %%
#make this back into a dataframe
pd_data = pd.DataFrame(cluster_googleplaydata)

# %%
cluster_googleplaydata.Installs.value_counts()

# %%
#make categories for the installs
bins = [0, 500, 100000, 1000000, 10000000]
#names = ['<2', '2-18', '18-35', '35-65', '65+']

cluster_googleplaydata['Installs'] = pd.cut(cluster_googleplaydata['Installs'], bins) #labels=names)

print(cluster_googleplaydata.dtypes)

# %%
#transform the string cateogorical variable types into encoded numbers denoting the category

# creating a dict file  
categories = {'FAMILY':0,'GAME':1,'TOOLS':2,'MEDICAL':3,'BUSINESS':4,'PRODUCTIVITY':5,'PERSONALIZATION':6,'COMMUNICATION':7,
          'SPORTS':8,'LIFESTYLE':9,'FINANCE':10,'HEALTH_AND_FITNESS':11,'PHOTOGRAPHY':12,'SOCIAL':13,'NEWS_AND_MAGAZINES':14,
          'SHOPPING':15,'TRAVEL_AND_LOCAL':16,'DATING':17,'BOOKS_AND_REFERENCE':18,'VIDEO_PLAYERS':19,'EDUCATION':20,
          'ENTERTAINMENT':21,'MAPS_AND_NAVIGATION':22,'FOOD_AND_DRINK':23,'HOUSE_AND_HOME':24,'LIBRARIES_AND_DEMO':25,
          'AUTO_AND_VEHICLES':26,'WEATHER':27,'ART_AND_DESIGN':28,'EVENTS':29,'PARENTING':30,'COMICS':31,'BEAUTY':32,'1.9':33}

# traversing through dataframe 
# Gender column and writing 
# values where key matches 
cluster_googleplaydata.Category = [categories[item] for item in cluster_googleplaydata.Category] 

print(cluster_googleplaydata)

# %%
plt.hist(cluster_googleplaydata['Size'])

# %%
#now we have to transform all the size values dynamically to floats

for item in cluster_googleplaydata.Size:

# %%
# K-Means Clustering

X = cluster_googleplaydata


#REMOVED AOVE: App  object

#Category           object
#Rating            float64
#Reviews            object
#Size               object
#Installs           object
#Type               object
#Price              object
#Content Rating     object
#Genres             object
#Last Updated       object
#Current Ver        object
#Android Ver        object

X = pd.DataFrame(X)
X = X.convert_objects(convert_numeric=True)
X.columns = ['Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# Eliminating null values
for i in X.columns:
    X[i] = X[i].fillna(int(X[i].mean()))
for i in X.columns:
    print(X[i].isnull().sum())
    

# Using the elbow method to find  the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# Applying k-means to the googleplaydata dataset
kmeans = KMeans(n_clusters=3,init='k-means++',max_iter=300,n_init=10,random_state=0) 
y_kmeans = kmeans.fit_predict(X)

X = X.as_matrix(columns=None)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0,1],s=100,c='red',label='US')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1,1],s=100,c='blue',label='Japan')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2,1],s=100,c='green',label='Europe')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='yellow',label='Centroids')
plt.title('Clusters of apps')
plt.legend()
plt.show()

# %%
#what is the general size of the apps in the play store?
np.where(googleplaydata['Size']>1000)
